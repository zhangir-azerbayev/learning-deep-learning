# %% [markdown]
# # Naive Bayes
# In this file we train a naive Bayes classifier on the MNIST dataset.

# %% [markdown]
# ## The Classifier
# Suppose we have a binary vector $x$ and we want to predict the most likely label $\hat{y}$. We want
#
# \begin{equation*}
# \hat{y} = \mathrm{argmax}_y p(y\mid x)
# \end{equation*}

# %% [markdown]
# We rewrite this as
#
# \begin{equation*}
# \hat{y} = \mathrm{argmax}_y p(y\mid x) = \mathrm{argmax}_y\frac{p(x\mid y)p(y)}{p(x)} \propto p(x\mid y)p(y)
# \end{equation*}

# %% [markdown]
# The crucial assumption we make is that each component of $x$ is conditionally independent given $y$ (which is not realistic at all). Thus
#
# \begin{equation*}
# \hat{y} = \mathrm{argmax}_y \prod_{i=1}^n p(x_i\mid y)p(y).
# \end{equation*}
#
# Of course we can easily estimate $p(x_i\mid y)$ and $p(y)$ from our training data.

# %% [markdown]
# To avoid numerical underflow, we instead compute
# \begin{equation*}
# \hat{y} = \mathrm{argmax}_y \sum_{i=1}^n\log p(x_i\mid y) + \log p(y)
# \end{equation*}

# %% [markdown]
# ## Implementation

# %%
import math
import torch
import torchvision
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
# %matplotlib inline
set_matplotlib_formats('svg')

# %%
# We first define a function that transforms each data point from
# a 28x28 array to a dimension 784 vector. 
# Then we download the data and apply the transformation. 

data_transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor()])

mnist_train = torchvision.datasets.MNIST(
    root='./data', train=True, transform=data_transform, 
    download=True)
mnist_test = torchvision.datasets.MNIST(
    root='./data', train=False, transform=data_transform, 
    download=True)

# %%
# Example data points
images = torch.stack([mnist_train[i][0] for i in range(10, 38)], 
                    dim=1).squeeze(0)
labels = torch.tensor([mnist_train[i][1] for i in range(10, 38)])

# Figure out how to display all of them. 
plt.imshow(images[5])

# %%
# Now we estimate p(y) for each y. 

X = torch.stack([mnist_train[i][0] for i in range(len(mnist_train))],
               dim=1).squeeze(0)

Y = torch.tensor([mnist_train[i][1] for i in range(len(mnist_train))])

n_y = torch.zeros(10)
for y in range(10):
    n_y[y] = (Y == y).sum()

P_y = n_y / n_y.sum()
P_y
# Out:
# tensor([0.0987, 0.1124, 0.0993, 0.1022, 0.0974, 0.0904, 0.0986, 0.1044, 0.0975,
#         0.0992])

# %% [markdown]
# In estimating $P(x_i\mid y)$, we run into the problem that some of the values might be 0. To do this, we just use add 1 to each count. This is called *Laplace smoothing*.

# %%
# Estimate p(x_i|y). 

n_x = torch.zeros((10, 28, 28))

for y in range(10): 
    n_x[y] = X[Y == y].sum(axis=0)

P_xy = (n_x + 1) / (n_y + 1).reshape(10, 1, 1)

plt.imshow(P_xy[3])

# %%
#We now implement the classifying function 

logP_xy = torch.log(P_xy)
logP_xy_c = torch.log(1 - P_xy)
logP_y = torch.log(P_y)

# x is (28, 28)
def bayes_pred(x):
    x = x.unsqueeze(0) # (28, 28) -> (1, 28, 28)
    p_xy = logP_xy * x + logP_xy_c * (1-x)
    p_xy = p_xy.reshape(10, -1).sum(axis=1)
    return p_xy + logP_y

py = bayes_pred(images[7])
py
# Out:
# tensor([-287.4762, -205.8065, -215.5989, -220.9649, -234.0170, -197.6193,
#         -278.7101, -247.4559, -161.8916, -222.7641])

# %%
# Now let's define a prediction function and do a test
def predict(X): 
    return [bayes_pred(x).argmax(dim=0) for x in X]

predict(images[7].unsqueeze(dim=0))[0] == labels[7]
# Out:
# tensor(True)

# %%
# Let's compute the overall accuracy of the classifier
X = torch.stack([mnist_train[i][0] for i in range(len(mnist_test))],
                dim=1).squeeze(0)
y = torch.tensor([mnist_train[i][1] for i in range(len(mnist_test))])

preds = torch.tensor(predict(X), dtype=torch.int32)
float((preds == y).sum()) / len(y)
# Out:
# 0.8364

# %% [markdown]
# Modern deep nets achieve error rates of less than 0.01. We can see that the assumption that all the pixels are independent was really fatal.
